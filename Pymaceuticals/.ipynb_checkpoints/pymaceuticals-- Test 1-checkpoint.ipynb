# %%
# Dependencies and Setup
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from scipy.stats import sem

# Hide warning messages in notebook
import warnings
warnings.filterwarnings('ignore')

# File to Load (Remember to Change These)
mouse_drug_data_to_load = "data/mouse_drug_data.csv"
clinical_trial_data_to_load = "data/clinicaltrial_data.csv"

# Read the Mouse and Drug Data and the Clinical Trial Data
mouse_data = pd.read_csv("data/mouse_drug_data.csv")
drug_data = pd.read_csv("data/clinicaltrial_data.csv")

# Combine the data into a single dataset
combine_df =pd.merge(mouse_data, drug_data, on="Mouse ID")

# Display the data table for preview

combine_df.head()
#drug_data
#mouse_data
# Out:
#   Mouse ID      Drug  Timepoint  Tumor Volume (mm3)  Metastatic Sites
# 0     f234  Stelasyn          0           45.000000                 0
# 1     f234  Stelasyn          5           47.313491                 0
# 2     f234  Stelasyn         10           47.904324                 0
# 3     f234  Stelasyn         15           48.735197                 1
# 4     f234  Stelasyn         20           51.112713                 2

# %% [markdown]
# ## Tumor Response to Treatment

# %%
# Store the Mean Tumor Volume Data Grouped by Drug and Timepoint

#tumor = combine_df.loc[combine_df["Drug"] == "Stelasyn"]
#print(tumor)
#tumor_data = tumor_data.groupby(["Drug"]).mean()
#tumor_data = tumor.groupby(["Timepoint"]).mean()
#tumorVOL_df = pd.DataFrame(tumor_data)


tumor_data = combine_df.groupby(["Drug", "Timepoint"])["Tumor Volume (mm3)"].mean()
tumorVOL_df = pd.DataFrame(tumor_data)
tumorVOL_df = tumorVOL_df.reset_index()
#print(tumor_data)

#tumorVOL_df


#plt.scatter(tumorVOL_df["Timepoint"], tumorVOL_df["Tumor Volume (mm3)"])
#plt.xlabel("Timepoint")
#plt.ylabel("Tumor Volume")
#plt.title("Tumor Response of Naftisol")
#plt.show()

uniques = tumorVOL_df["Drug"].unique()
print(uniques)
tumorVOL_df
# Out:
# ['Capomulin' 'Ceftamin' 'Infubinol' 'Ketapril' 'Naftisol' 'Placebo'
#  'Propriva' 'Ramicane' 'Stelasyn' 'Zoniferol']
#          Drug  Timepoint  Tumor Volume (mm3)
# 0   Capomulin          0           45.000000
# 1   Capomulin          5           44.266086
# 2   Capomulin         10           43.084291
# 3   Capomulin         15           42.064317
# 4   Capomulin         20           40.716325
# ..        ...        ...                 ...
# 95  Zoniferol         25           55.432935
# 96  Zoniferol         30           57.713531
# 97  Zoniferol         35           60.089372
# 98  Zoniferol         40           62.916692
# 99  Zoniferol         45           65.960888
#
# [100 rows x 3 columns]

# %%
colors = ["red", "blue", "yellow", "orange", "green", "black", "cyan", "purple", "grey", "brown"]
dfList = []
count = 0
for drug in uniques:
    newDf = tumorVOL_df.loc[tumorVOL_df["Drug"]==drug]
    dfList.append(newDf)
    
#print(dfList)

for df in dfList:
    plt.scatter(dfList[count]["Timepoint"], dfList[count]["Tumor Volume (mm3)"], color=colors[count])
    count +=1


#capDF = tumorVOL_df.loc[tumorVOL_df["Drug"]=="Capomulin"]
#print(capDF)

plt.xlabel("Timepoint")
plt.ylabel("Tumor Volume")
plt.title("Tumor Response to Treatment")
plt.show()

#plt.scatter(DFList[0:]["Timepoint"], capDF["Tumor Volume (mm3)"], color=colors[0:])
#plt.scatter(DFList[1]["Timepoint"], capDF["Tumor Volume (mm3)"], color=colors[1])

# %%
#error = tumorVOL_df.sem(axis=1)
#error_df =

# %%
# Store the Standard Error of Tumor Volumes Grouped by Drug and Timepoint
tumorError = combine_df.groupby(["Drug", "Timepoint"]).sem()["Tumor Volume (mm3)"]

# Convert to DataFrame
tumorError_df = pd.DataFrame(tumorError)
#tumorError_df = tumorError_df.rename(columns= {'Tumor Volume (mm3)':'Standard Error (Tumor Volume)'})

# Preview DataFrame

print(tumorError_df.columns)
tumorError_df.reset_index()
# Out:
# Index(['Tumor Volume (mm3)'], dtype='object')
#          Drug  Timepoint  Tumor Volume (mm3)
# 0   Capomulin          0            0.000000
# 1   Capomulin          5            0.448593
# 2   Capomulin         10            0.702684
# 3   Capomulin         15            0.838617
# 4   Capomulin         20            0.909731
# ..        ...        ...                 ...
# 95  Zoniferol         25            0.602513
# 96  Zoniferol         30            0.800043
# 97  Zoniferol         35            0.881426
# 98  Zoniferol         40            0.998515
# 99  Zoniferol         45            1.003576
#
# [100 rows x 3 columns]

# %%
errorDF = tumorError_df.reset_index()
errorDF.pivot(index="Timepoint", columns="Drug")["Tumor Volume (mm3)"]
# Out:
# Drug       Capomulin  Ceftamin  Infubinol  Ketapril  Naftisol   Placebo  \
# Timepoint
# 0           0.000000  0.000000   0.000000  0.000000  0.000000  0.000000
# 5           0.448593  0.164505   0.235102  0.264819  0.202385  0.218091
# 10          0.702684  0.236144   0.282346  0.357421  0.319415  0.402064
# 15          0.838617  0.332053   0.357705  0.580268  0.444378  0.614461
# 20          0.909731  0.359482   0.476210  0.726484  0.595260  0.839609
# 25          0.881642  0.439356   0.550315  0.755413  0.813706  1.034872
# 30          0.934460  0.490620   0.631061  0.934121  0.975496  1.218231
# 35          1.052241  0.692248   0.984155  1.127867  1.013769  1.287481
# 40          1.223608  0.708505   1.055220  1.158449  1.118567  1.370634
# 45          1.223977  0.902358   1.144427  1.453186  1.416363  1.351726
#
# Drug       Propriva  Ramicane  Stelasyn  Zoniferol
# Timepoint
# 0          0.000000  0.000000  0.000000   0.000000
# 5          0.231708  0.482955  0.239862   0.188950
# 10         0.376195  0.720225  0.433678   0.263949
# 15         0.466109  0.770432  0.493261   0.370544
# 20         0.555181  0.786199  0.621889   0.533182
# 25         0.577401  0.746991  0.741922   0.602513
# 30         0.746045  0.864906  0.899548   0.800043
# 35         1.084929  0.967433  1.003186   0.881426
# 40         1.564779  1.128445  1.410435   0.998515
# 45         1.888586  1.226805  1.576556   1.003576

# %%
# Minor Data Munging to Re-Format the Data Frames

# Preview that Reformatting worked

# %%
# Generate the Plot (with Error Bars)
semList = []

for drug in uniques:
    new_semDf = errorDF.loc[errorDF["Drug"]==drug]
    semList.append(new_semDf)

print(semList[1])

for df in dfList:
    plt.scatter(semList[count]["Timepoint"], semList[count]["Tumor Volume (mm3)"], color=colors[count])
    count +=1

plt.xlabel("Timepoint")
plt.ylabel("Tumor Volume")
plt.title("Tumor Volume Over Time")
plt.show()



#plt.scatter(tumorError_df["Timepoint"], tumorError_df["Tumor Volume (mm3)"])

#plt.xlabel("Timepoint")
#plt.ylabel("Tumor Volume")
#plt.title("Tumor Volume Over Time")
#plt.show()
# Save the Figure
# Out:
#         Drug  Timepoint  Tumor Volume (mm3)
# 10  Ceftamin          0            0.000000
# 11  Ceftamin          5            0.164505
# 12  Ceftamin         10            0.236144
# 13  Ceftamin         15            0.332053
# 14  Ceftamin         20            0.359482
# 15  Ceftamin         25            0.439356
# 16  Ceftamin         30            0.490620
# 17  Ceftamin         35            0.692248
# 18  Ceftamin         40            0.708505
# 19  Ceftamin         45            0.902358
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-15-60fab3e7301d> in <module>
#       9
#      10 for df in dfList:
# ---> 11     plt.scatter(semList[count]["Timepoint"], semList[count]["Tumor Volume (mm3)"], color=colors[count])
#      12     count +=1
#      13
#
# IndexError: list index out of range

# %%
# Show the Figure
plt.show()

# %%
combine_df

# %% [markdown]
# ![Tumor Response to Treatment](../Images/treatment.png)

# %% [markdown]
# ## Metastatic Response to Treatment

# %%
# Store the Mean Met. Site Data Grouped by Drug and Timepoint
metastatic_data = combine_df.groupby(["Drug", "Timepoint"])["Metastatic Sites"].mean()

# Convert to DataFrame
metastatic_dataDF = pd.DataFrame(metastatic_data)
# Preview DataFrame
metastatic_dataDF

# %%
# Store the Standard Error associated with Met. Sites Grouped by Drug and Timepoint 
metastaticError = combine_df.groupby(["Drug", "Timepoint"])["Metastatic Sites"].sem()
# Convert to DataFrame
metastaticError_df = pd.DataFrame(metastaticError)
# Preview DataFrame
metastaticError_df

# %%
# Minor Data Munging to Re-Format the Data Frames

# Preview that Reformatting worked

# %%
# Generate the Plot (with Error Bars)

# Save the Figure

# Show the Figure

# %% [markdown]
# ![Metastatic Spread During Treatment](../Images/spread.png)

# %% [markdown]
# ## Survival Rates

# %%
# Store the Count of Mice Grouped by Drug and Timepoint (W can pass any metric)

# Convert to DataFrame

# Preview DataFrame

# %%
# Minor Data Munging to Re-Format the Data Frames

# Preview the Data Frame

# %%
# Generate the Plot (Accounting for percentages)

# Save the Figure

# Show the Figure
plt.show()

# %% [markdown]
# ![Metastatic Spread During Treatment](../Images/survival.png)

# %% [markdown]
# ## Summary Bar Graph

# %%
# Calculate the percent changes for each drug

# Display the data to confirm

# %%
# Store all Relevant Percent Changes into a Tuple


# Splice the data between passing and failing drugs


# Orient widths. Add labels, tick marks, etc. 


# Use functions to label the percentages of changes


# Call functions to implement the function calls


# Save the Figure


# Show the Figure
fig.show()

# %% [markdown]
# ![Metastatic Spread During Treatment](../Images/change.png)
